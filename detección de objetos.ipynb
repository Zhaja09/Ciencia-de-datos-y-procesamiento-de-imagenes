# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow



original = cv2.imread("/content/1.jpg")
cv2.imread("original", original)
gris = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
gauss =cv2.GaussianBlur(gris, (5,5), 0)
cv2.imshow("suavisado", gauss)
canny = cv2.Canny(gauss, 50, 150)
cv2.imshow("canny", canny)
(contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print("he encontrado {} objetos".format(len(contornos)))
cv2.drawContours(original, contornos, -1, (0,0,255),2)
cv2.imshow("contornos", original)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37b3708e6acb> in <cell line: 8>()
#       6
#       7 original = cv2.imread("/content/1.jpg")
# ----> 8 cv2_imread("original", original)
#       9 gris = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
#      10 gauss =cv2.GaussianBlur(gris, (5,5), 0)
#
# NameError: name 'cv2_imread' is not defined

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow



original = cv2.imread("/content/1.jpg")
#cv2_imread(original)
gris = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
gauss =cv2.GaussianBlur(gris, (5,5), 0)
cv2_imshow(gauss)
canny = cv2.Canny(gauss, 50, 150)
cv2_imshow(canny)
(contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print("he encontrado {} objetos".format(len(contornos)))
cv2.drawContours(original, contornos, -1, (0,0,255),2)
cv2_imshow(original)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
