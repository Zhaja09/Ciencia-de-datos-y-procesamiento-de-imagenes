# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.draw import polygon
from skimage import draw

def dibujocuadrado1(r1,r2,r3,r4,r5, c1,c2,c3,c4,c5):

    imagen = io.imread("/content/cuales-son-los-5-tipos-de-imagen.png")
    r, c =[r1,r2,r3,r4,r5],[c1,c2,c3,c4,c5]
    rr, cc = draw.polygon(r, c)
    imagen [rr, cc]=0
    io.imshow(imagen)

dibujocuadrado1(200,400,400,200,300,200,200,400,400,300)

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.draw import polygon
from skimage import draw
import matplotlib.pyplot as plt

def whilefor():
    imagen = io.imread("/content/cuales-son-los-5-tipos-de-imagen.png")
    count = 0
    while count <4:
        for _ in range (2):
            x = range(0,700,5)
            y = range(0,1200,5)
            xx,yy = draw.polygon (x,y)
            imagen [xx,yy]=0
            count += 1
    io.imshow(imagen)
    io.show()
whilefor()

# %%
import matplotlib.pyplot as plt

# Create a list of x-coordinates.
x_coords = []

# Create a list of y-coordinates.
y_coords = []

# Use a for loop to generate 100 points.
for i in range(100):
  # Generate a random x-coordinate between 0 and 1.
  x = random.random()

  # Generate a random y-coordinate between 0 and 1.
  y = random.random()

  # Add the coordinates to the lists.
  x_coords.append(x)
  y_coords.append(y)

# Create the figure.
plt.figure()

# Plot the points.
plt.plot(x_coords, y_coords, 'o')

# Show the figure.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b3e771067887> in <cell line: 10>()
#      10 for i in range(100):
#      11   # Generate a random x-coordinate between 0 and 1.
# ---> 12   x = random.random()
#      13
#      14   # Generate a random y-coordinate between 0 and 1.
#
# NameError: name 'random' is not defined
