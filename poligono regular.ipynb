# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.draw import polygon
from skimage import draw

def dibujocuadrado2(r1,r2,r3,r4,r5,r6,r7,r8,r9,
          c1,c2,c3,c4,c5,c6,c7,c8,c9):

  imagen = io.imread("/content/1231.png")
  r, c =[r1,r2,r3,r4,r5,r6,r7,r8,r8,r9,],[c1,c2,c3,c4,c5,c6,c7,c8,c9,]
  rr, cc = draw.polygon(r, c)
  imagen [rr, cc]=0
  io.imshow(imagen)

dibujocuadrado2(200,300,400,600,450,550,400,350,200, 100,200,80,300,400,600,700,650,600)
